# %%
[1,2,3]*3
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
[1,2,3] + [4,5,6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a = [1,2,3]
a.extend([4,5,6])
print(a)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
import pandas as pd
import numpy as np

# %%
data = {'Sport': ['Basketball', 'Football', 'Cricket'],
        'Age': [26, 26, 27]}

# %%
df = pd.DataFrame(data=data)

# %%
df
# Out:
#         Sport  Age
# 0  Basketball   26
# 1    Football   26
# 2     Cricket   27

# %%
df['Olympics'] = [1]*df.shape[0]

# %%
df.shape
# Out:
# (3, 3)

# %%
df
# Out:
#         Sport  Age  Olympics
# 0  Basketball   26         1
# 1    Football   26         1
# 2     Cricket   27         1

# %%
df['Data'] = np.ones(df.shape[0], dtype=int)

# %%
df
# Out:
#         Sport  Age  Olympics  Data
# 0  Basketball   26         1     1
# 1    Football   26         1     1
# 2     Cricket   27         1     1

# %%
np.ones?

# %%
jobs = pd.read_csv('./brighter_monday/brighter_monday_jobs.csv')

# %%
jobs
# Out:
#                                             title  \
# 0     Writing and Document Management Consultancy
# 1                           Automotive Technician
# 2                       Business Development Lead
# 3                                    Head Teacher
# 4                         Primary School Teachers
# ...                                           ...
# 1065        ANTI-PIRACY AND SECURITY INVESTIGATOR
# 1066              COMMERCIAL LEGALIZATION OFFICER
# 1067                                     Teachers
# 1068                                          NaN
# 1069                                          NaN
#
#                        organization                                function  \
# 0           \nAgri Experience Ltd\n               \nConsulting & Strategy\n
# 1                 \n Confidential\n            \nEngineering & Technology\n
# 2             \nAltima Africa Ltd\n  \n Management & Business Development\n
# 3                  \nConfidential\n       \nResearch, Teaching & Training\n
# 4                  \nConfidential\n       \nResearch, Teaching & Training\n
# ...                             ...                                     ...
# 1065  \nBrighterMonday Consulting\n        \nProduct & Project Management\n
# 1066  \nBrighterMonday Consulting\n        \nProduct & Project Management\n
# 1067       \nThe Visionary School\n       \nResearch, Teaching & Training\n
# 1068                            NaN                                     NaN
# 1069                            NaN                                     NaN
#
#                                             description  \
# 0     \nAgri Experience seeks a high quality and exp...
# 1     \nApplications are invited from qualified pers...
# 2     \nResponsible for the execution of the firm’s ...
# 3     \nThe purpose of this position is to provide a...
# 4     \nPrimary School teachers create daily lesson ...
# ...                                                 ...
# 1065  \nThe role holder will be responsible for over...
# 1066  \nThe role holder will be responsible for mana...
# 1067  \nApplications are invited from qualified pers...
# 1068                                                NaN
# 1069                                                NaN
#
#                                                     url
# 0     https://www.brightermonday.co.ke/listings/writ...
# 1     https://www.brightermonday.co.ke/listings/auto...
# 2     https://www.brightermonday.co.ke/listings/busi...
# 3     https://www.brightermonday.co.ke/listings/head...
# 4     https://www.brightermonday.co.ke/listings/prim...
# ...                                                 ...
# 1065  https://www.brightermonday.co.ke/listings/anti...
# 1066  https://www.brightermonday.co.ke/listings/comm...
# 1067  https://www.brightermonday.co.ke/listings/teac...
# 1068                                                NaN
# 1069                                                NaN
#
# [1070 rows x 5 columns]

# %%
jobs.isnull().sum()
# Out:
# title            98
# organization     98
# function         98
# description     502
# url              98
# dtype: int64

# %%
1302-116
# Out:
# 1186

# %%
vaccinations = pd.read_csv("https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/vaccinations.csv", error_bad_lines=False)

# %%
vaccinations.head()
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 0                                  NaN                             NaN
# 1                                  NaN                            35.0
# 2                                  NaN                            35.0
# 3                                  NaN                            35.0
# 4                                  NaN                            35.0

# %%
vaccinations['date'] = pd.to_datetime(vaccinations['date'])

# %%
idx_max = vaccinations.groupby(['location'])['date'].idxmax()

# %%
latest_vaccination_data = vaccinations.loc[idx_max].reset_index(drop=True)

# %%
latest_vaccination_data.head()
# Out:
#       location  iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan       AFG 2021-04-22            240000.0           240000.0
# 1       Africa  OWID_AFR 2021-04-27          17147135.0         12159279.0
# 2      Albania       ALB 2021-04-24            400064.0                NaN
# 3      Algeria       DZA 2021-02-19             75000.0                NaN
# 4      Andorra       AND 2021-04-19             26414.0            21733.0
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN              8000.0
# 1                4775479.0                133576.0            116583.0
# 2                      NaN                  8713.0             10746.0
# 3                      NaN                     NaN              3748.0
# 4                   4681.0                     NaN              1050.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                            0.62                           0.62
# 1                            1.28                           0.91
# 2                           13.90                            NaN
# 3                            0.17                            NaN
# 4                           34.19                          28.13
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 0                                  NaN                           206.0
# 1                                 0.36                            87.0
# 2                                  NaN                          3734.0
# 3                                  NaN                            85.0
# 4                                 6.06                         13590.0

# %%
population_data_2020 = pd.read_csv('https://raw.githubusercontent.com/owid/covid-19-data/master/scripts/input/un/population_2020.csv')

# %%
population_data_2020.head()
# Out:
#            entity iso_code  year  population
# 0     Afghanistan      AFG  2020    38928341
# 1         Albania      ALB  2020     2877800
# 2         Algeria      DZA  2020    43851043
# 3  American Samoa      ASM  2020       55197
# 4         Andorra      AND  2020       77265

# %%
population_data_2020.shape
# Out:
# (248, 4)

# %%
vaccination_population = pd.merge(latest_vaccination_data, population_data_2020, how='left', left_on='location', right_on='entity')

# %%
vaccination_population
# Out:
#         location iso_code_x       date  total_vaccinations  people_vaccinated  \
# 0    Afghanistan        AFG 2021-04-22        2.400000e+05           240000.0
# 1         Africa   OWID_AFR 2021-04-27        1.714714e+07         12159279.0
# 2        Albania        ALB 2021-04-24        4.000640e+05                NaN
# 3        Algeria        DZA 2021-02-19        7.500000e+04                NaN
# 4        Andorra        AND 2021-04-19        2.641400e+04            21733.0
# ..           ...        ...        ...                 ...                ...
# 196      Vietnam        VNM 2021-04-27        3.187920e+05           318792.0
# 197        Wales   OWID_WLS 2021-04-26        2.486446e+06          1785347.0
# 198        World   OWID_WRL 2021-04-27        1.061180e+09        570626607.0
# 199       Zambia        ZMB 2021-04-25        1.401200e+04            14012.0
# 200     Zimbabwe        ZWE 2021-04-27        4.339390e+05           370676.0
#
#      people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                        NaN                     NaN              8000.0
# 1                  4775479.0                133576.0            116583.0
# 2                        NaN                  8713.0             10746.0
# 3                        NaN                     NaN              3748.0
# 4                     4681.0                     NaN              1050.0
# ..                       ...                     ...                 ...
# 196                      NaN                 59056.0             30266.0
# 197                 701099.0                 19537.0             25210.0
# 198              248367721.0              16479638.0          17543872.0
# 199                      NaN                     NaN              1814.0
# 200                  63263.0                 22329.0             15562.0
#
#      total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                              0.62                           0.62
# 1                              1.28                           0.91
# 2                             13.90                            NaN
# 3                              0.17                            NaN
# 4                             34.19                          28.13
# ..                              ...                            ...
# 196                            0.33                           0.33
# 197                           78.86                          56.63
# 198                           13.61                           7.32
# 199                            0.08                           0.08
# 200                            2.92                           2.49
#
#      people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                    NaN                           206.0
# 1                                   0.36                            87.0
# 2                                    NaN                          3734.0
# 3                                    NaN                            85.0
# 4                                   6.06                         13590.0
# ..                                   ...                             ...
# 196                                  NaN                           311.0
# 197                                22.24                          7996.0
# 198                                 3.19                          2251.0
# 199                                  NaN                            99.0
# 200                                 0.43                          1047.0
#
#           entity iso_code_y    year    population
# 0    Afghanistan        AFG  2020.0  3.892834e+07
# 1         Africa   OWID_AFR  2020.0  1.340598e+09
# 2        Albania        ALB  2020.0  2.877800e+06
# 3        Algeria        DZA  2020.0  4.385104e+07
# 4        Andorra        AND  2020.0  7.726500e+04
# ..           ...        ...     ...           ...
# 196      Vietnam        VNM  2020.0  9.733858e+07
# 197          NaN        NaN     NaN           NaN
# 198        World   OWID_WRL  2020.0  7.794799e+09
# 199       Zambia        ZMB  2020.0  1.838396e+07
# 200     Zimbabwe        ZWE  2020.0  1.486293e+07
#
# [201 rows x 16 columns]

# %%
vaccination_population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 201 entries, 0 to 200
# Data columns (total 16 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   location                             201 non-null    object
#  1   iso_code_x                           201 non-null    object
#  2   date                                 201 non-null    datetime64[ns]
#  3   total_vaccinations                   199 non-null    float64
#  4   people_vaccinated                    189 non-null    float64
#  5   people_fully_vaccinated              126 non-null    float64
#  6   daily_vaccinations_raw               109 non-null    float64
#  7   daily_vaccinations                   192 non-null    float64
#  8   total_vaccinations_per_hundred       199 non-null    float64
#  9   people_vaccinated_per_hundred        189 non-null    float64
#  10  people_fully_vaccinated_per_hundred  126 non-null    float64
#  11  daily_vaccinations_per_million       192 non-null    float64
#  12  entity                               196 non-null    object
#  13  iso_code_y                           196 non-null    object
#  14  year                                 196 non-null    float64
#  15  population                           196 non-null    float64
# dtypes: datetime64[ns](1), float64(11), object(4)
# memory usage: 26.7+ KB

# %%
vaccination_population['% population vaccinated'] = vaccination_population['people_vaccinated'] / vaccination_population['population'] * 100

# %%
top_3_countries = vaccination_population.sort_values(by='% population vaccinated', ascending=False)[['location', 'iso_code_x', 'date', 'people_vaccinated', 'population', '% population vaccinated']][:3]

# %%
top_3_countries
# Out:
#              location iso_code_x       date  people_vaccinated  population  \
# 69          Gibraltar        GIB 2021-04-27            36724.0     33691.0
# 60   Falkland Islands        FLK 2021-04-14             2632.0      3483.0
# 161        Seychelles        SYC 2021-04-26            66583.0     98340.0
#
#      % population vaccinated
# 69                109.002404
# 60                 75.567040
# 161                67.706935
